# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained("facebook/opt-350m")

# %%
# creat ethe peftr config
from peft import LoraConfig, TaskType


lora_config = LoraConfig(
    r=16,
    target_modules=["q_proj", "v_proj"],
    task_type=TaskType.CAUSAL_LM,
    lora_alpha=32,
    lora_dropout=0.05
)

# %%
from peft import get_peft_model
lora_model = get_peft_model(model,lora_config)

# %%
lora_model.print_trainable_parameters()
# Out:
# trainable params: 1,572,864 || all params: 332,769,280 || trainable%: 0.4727

# %%
# to load the peft model for iunferenace
from transformers import pipeline

generator  = pipeline(model="facebook/opt-350m")

generator("Hello")
# Out:
# Device set to use mps:0
# [{'generated_text': "Hello, I'm a newbie to this sub. I'm looking for a good place to"}]

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-350m")

# Load the model
model = AutoModelForCausalLM.from_pretrained("facebook/opt-350m")

# %%
# Example input text
input_text = "Hello"

# Tokenize the input text
input_ids = tokenizer.encode(input_text, return_tensors="pt")
input_ids
# Out:
# tensor([[    2, 31414]])

# %%
# Generate output
output = model.generate(
    input_ids,
    max_length=100,
    num_beams=5,
    temperature=0.7,
    top_k=50,
    top_p=0.95,
    num_return_sequences=1
)
# Decode the output to get the text
output_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(output_text)
# Out:
# Hello, I have an egg that matches your TSV. Would you mind hatching it for me? Thanks in advance!
# Sure thing! I'll add you now.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-350m")
model = AutoModelForCausalLM.from_pretrained("facebook/opt-350m")

# Prepare the input
input_text = "Hello"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate output
output = model.generate(input_ids, max_length=50, num_return_sequences=1)

# Decode the output
output_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(output_text)
# Out:
# Hello, I'm a newbie to this sub. I'm looking for a good place to start. I'm looking for a place to start with a good community. I'm looking for a place to start with a good community. I'm

# %%
from  transformers import AutoTokenizer, AutoModelForCausalLM

checkpoint = "facebook/opt-350m"
input_sequence = "Hello"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
tokenized_input = tokenizer(input_sequence, return_tensors="pt")

tokenized_input
# Out:
# {'input_ids': tensor([[    2, 31414]]), 'attention_mask': tensor([[1, 1]])}

# %%
import torch
model = AutoModelForCausalLM.from_pretrained(checkpoint)

with torch.inference_mode():
    out = model.generate(**tokenized_input)
    
out[0]
# Out:
# tensor([    2, 31414,     6,    38,   437,    10,    92, 12750,     7,    42,
#          2849,     4,    38,   437,   546,    13,    10,   205,   317,     7,
#           386,     4])

# %%
tokenizer.decode(out[0])
# Out:
# "</s>Hello, I'm a newbie to this sub. I'm looking for a good place to start."
