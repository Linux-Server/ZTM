# %%
# import tensorflow
import tensorflow as tf


tf.__version__
# Out:
# '2.19.0'

# %%
# create a scalar
scalar = tf.constant([[10]])

scalar
# Out:
# <tf.Tensor: shape=(1, 1), dtype=int32, numpy=array([[10]], dtype=int32)>

# %%
scalar.ndim , scalar.shape, scalar.dtype
# Out:
# (2, TensorShape([1, 1]), tf.int32, array([[10]], dtype=int32))

# %%
scalar.numpy()
# Out:
# array([[10]], dtype=int32)

# %%
matric = tf.constant([[10,7],
                      [3,8]]
                    )
matric
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[10,  7],
#        [ 3,  8]], dtype=int32)>

# %%
matric.shape
# Out:
# TensorShape([2, 2])

# %%
matric[0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([10,  7], dtype=int32)>

# %%
one = tf.constant([[9.0, 10.0]])

# %%
one
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[ 9., 10.]], dtype=float32)>
